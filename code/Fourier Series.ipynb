# %%
from sympy import *
from sympy.plotting import plot
# %matplotlib inline

# %%
def e(k):
    "k-esimo elemento della base hilbertiana"
    k = Integer(k)
    if k == 0: 
        return lambda x: 1/sqrt(2*pi)
    elif k % 2 == 0: 
        return lambda x: cos(k/2 * x)/sqrt(pi)
    else: 
        return lambda x: sin((k+1)/2 * x)/sqrt(pi)

def f(g):
    "integra g contro la funzione che vale 1 in (0,pi) e -11 in (pi,2*pi)"
    x = symbols("x")
    return integrate(g(x), (x, 0, pi)) - integrate(g(x), (x, pi, 2*pi)) 

def fourier(f, n):
    "calcola l'n-esimo polinomio trigonometrico approssimante f"
    return lambda x: sum([f(e(k)) * e(k)(x) for k in range(n+1)])

# %%
"""
elenca e disegna gli sviluppi di Fourier di f
"""
x = symbols('x')
k = 15
order = 4*k+1
print("polinomio trigonometrico di ordine {}".format(order))
pol = fourier(f,k*4+1)(x)
print(pol)
p = plot(pol, (x, 0, 2*pi))
fig = p.backend(p)
fig.process_series()
fig.fig.savefig("fourier.png", dpi=600)
# Out:
# polinomio trigonometrico di ordine 61
# 4*sin(x)/pi + 4*sin(3*x)/(3*pi) + 4*sin(5*x)/(5*pi) + 4*sin(7*x)/(7*pi) + 4*sin(9*x)/(9*pi) + 4*sin(11*x)/(11*pi) + 4*sin(13*x)/(13*pi) + 4*sin(15*x)/(15*pi) + 4*sin(17*x)/(17*pi) + 4*sin(19*x)/(19*pi) + 4*sin(21*x)/(21*pi) + 4*sin(23*x)/(23*pi) + 4*sin(25*x)/(25*pi) + 4*sin(27*x)/(27*pi) + 4*sin(29*x)/(29*pi) + 4*sin(31*x)/(31*pi)

# %%
def ff(g):
    "integra g contro la funzione che vale x in (0,2pi)"
    x = symbols("x")
    return integrate(x*g(x), (x, 0, 2*pi))

# %%
ff(e(0))
# Out:
# sqrt(2)*pi**(3/2)

# %%
ff(e(1))
# Out:
# -2*sqrt(pi)

# %%
ff(e(2))
# Out:
# 0

# %%
ff(e(3))
# Out:
# -sqrt(pi)

# %%
ff(e(4))
# Out:
# 0
